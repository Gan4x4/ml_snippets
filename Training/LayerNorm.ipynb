# %%
from re import L
from torch.nn import LayerNorm

ln = LayerNorm((32,32))
for name, p in ln.named_parameters():
  print(name,p.shape)
# Out:
# weight torch.Size([32, 32])
# bias torch.Size([32, 32])
