# %%
from torchvision import models
import torch

alexnet = models.alexnet(weights="AlexNet_Weights.DEFAULT")
dummy_input = torch.randn(1,3,224,224)

# %%
import matplotlib.pyplot as plt


pic = dummy_input.permute(0,3,1,2).numpy()
print(pic.shape)
#plt.show(pic[0])
# Out:
# (1, 224, 3, 224)
